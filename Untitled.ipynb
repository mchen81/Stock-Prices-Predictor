# %%
import glob
import pandas as pd

# get data file names
path =r'totalCSV'
filenames = glob.glob(path + "/*.csv")

df_empty = pd.DataFrame(columns=[])
for filename in filenames:
    df_empty[filename] = pd.read_csv(filename)['Open']
df_empty
# Out:
#       totalCSV/CSCO.csv  totalCSV/CSBK.csv  totalCSV/SBGI.csv  \
# 0              0.000000              10.11              11.75
# 1              0.000000              10.13              11.75
# 2              0.000000              10.07              11.75
# 3              0.000000              10.22              11.75
# 4              0.000000              10.16              11.75
# ...                 ...                ...                ...
# 7828          49.189999                NaN                NaN
# 7829          49.610001                NaN                NaN
# 7830          48.520000                NaN                NaN
# 7831          48.709999                NaN                NaN
# 7832          48.939999                NaN                NaN
#
#       totalCSV/UFCS.csv  totalCSV/GFED.csv  totalCSV/AIRT.csv  \
# 0              0.000000           4.142931           2.916667
# 1              2.034568           4.272398           2.916667
# ...
